# %%
import pandas as pd
import numpy as np

# %%
#Question1
data=pd.read_csv('neet_data.csv')
data.head()
# Out:
#             created_at  retweet_count               source  \
# 0  2020-10-31 14:10:28            141  Twitter for Android
# 1  2020-10-31 14:10:11              1   Twitter for iPhone
# 2  2020-10-31 14:09:48            141      Twitter Web App
# 3  2020-10-31 14:09:41            141  Twitter for Android
# 4  2020-10-31 14:09:22              0  Twitter for Android
#
#                user_id     user_name  \
# 0  1250294694937915394          Rumi
# 1             57059492    Tom Bewick
# 2           1016022678      Lemonade
# 3  1085818329816883201       The Rus
# 4  1227501071490113537  Sakshi Yadav
#
#                                     user_description  user_follower_count  \
# 0                                                NaN                   14
# 1  Proud dad of three & cat, @SussexCCC fan. CEO ...                 2314
# 2  Wisdom is knowing the right path to take, Inte...                  285
# 3                                                NaN                  147
# ...

# %%
#Question2
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47381 entries, 0 to 47380
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           47381 non-null  object
#  1   retweet_count        47381 non-null  int64
#  2   source               47362 non-null  object
#  3   user_id              47381 non-null  int64
#  4   user_name            47380 non-null  object
#  5   user_description     36510 non-null  object
#  6   user_follower_count  47381 non-null  int64
#  7   user_friends_count   47381 non-null  int64
#  8   user_location        26247 non-null  object
#  9   user_verified        47381 non-null  bool
#  10  user_url             9280 non-null   object
#  11  tweet                47381 non-null  object
#  12  length_of_tweet      47381 non-null  int64
# dtypes: bool(1), int64(5), object(7)
# memory usage: 4.4+ MB

# %%
#Question3
data.sort_values(by='retweet_count',ascending=False,inplace=True)

# %%
#Question4
data.iloc[0,[2,6,7,4,11,0,10]]
# Out:
# source                                                Twitter for iPhone
# user_follower_count                                                   62
# user_friends_count                                                   115
# user_name                           \xe3\x81\xb2\xe3\x81\x88\xe3\x81\xa3
# tweet                  RT @JoeBiden: America, I\xe2\x80\x99m honored ...
# created_at                                           2020-11-08 05:30:01
# user_url                                         https://t.co/cHZdP4uOdu
# Name: 32860, dtype: object

# %%
#Question5
count=data['retweet_count'].head(10).sum()
print('Top 10 Retweet sum is',count)
# Out:
# Top 10 Retweet sum is 2652225

# %%
#Question6
count=data[data['source']=='Twitter for Android']['retweet_count'].count()
print(count)
sum=data[data['source']=='Twitter for Android']['retweet_count'].sum()
print(sum)
# Out:
# 28850
# 9386742

# %%
#Question7
data.sort_values(by='user_follower_count',ascending=False,inplace=True)
data.iloc[0,[4,8]]
# Out:
# user_name         NDTV
# user_location    India
# Name: 44367, dtype: object

# %%
#Question8
data['followers_friend_ratio']=data['user_follower_count']/data['user_friends_count']
data
# Out:
#                 created_at  retweet_count                          source  \
# 44367  2020-11-01 10:45:04             24  Twitter Media Studio - LiveCut
# 44424  2020-11-01 10:01:49             11  Twitter Media Studio - LiveCut
# 44355  2020-11-01 10:49:41             15  Twitter Media Studio - LiveCut
# 44436  2020-11-01 09:57:24             14  Twitter Media Studio - LiveCut
# 23641  2020-10-30 08:58:00              2                 Twitter Web App
# ...                    ...            ...                             ...
# 14011  2020-10-26 17:37:27              0                 Twitter Web App
# 9520   2020-10-28 14:00:49            175                 Twitter Web App
# 30211  2020-10-28 14:00:49            175                 Twitter Web App
# 23409  2020-10-30 09:59:50              0             Twitter for Android
# 20778  2020-10-31 13:37:47            201             Twitter for Android
#
#                    user_id          user_name  \
# ...

# %%
#Question9
data.isnull().sum()
# Out:
# created_at                    0
# retweet_count                 0
# source                       19
# user_id                       0
# user_name                     1
# user_description          10871
# user_follower_count           0
# user_friends_count            0
# user_location             21134
# user_verified                 0
# user_url                  38101
# tweet                         0
# length_of_tweet               0
# followers_friend_ratio      147
# dtype: int64

# %%
#Question10
data['user_description'].fillna('Twitter User',inplace=True)
data
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18140\3271653713.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['user_description'].fillna('Twitter User',inplace=True)
#                 created_at  retweet_count                          source  \
# 44367  2020-11-01 10:45:04             24  Twitter Media Studio - LiveCut
# 44424  2020-11-01 10:01:49             11  Twitter Media Studio - LiveCut
# 44355  2020-11-01 10:49:41             15  Twitter Media Studio - LiveCut
# ...

# %%
#Question11
data.dropna(axis=1,inplace=True)
data
# Out:
#                 created_at  retweet_count              user_id  \
# 44367  2020-11-01 10:45:04             24             37034483
# 44424  2020-11-01 10:01:49             11             37034483
# 44355  2020-11-01 10:49:41             15             37034483
# 44436  2020-11-01 09:57:24             14             37034483
# 23641  2020-10-30 08:58:00              2             37034483
# ...                    ...            ...                  ...
# 14011  2020-10-26 17:37:27              0  1307231165506416640
# 9520   2020-10-28 14:00:49            175  1306828323058671616
# 30211  2020-10-28 14:00:49            175  1306828323058671616
# 23409  2020-10-30 09:59:50              0  1296322416218578944
# 20778  2020-10-31 13:37:47            201  1312963204448948229
#
#                                         user_description  user_follower_count  \
# 44367  Breaking news alerts from India.\n\nInstagram:...             13934355
# ...

# %%
#Question12
data.insert(2,'is_allow',True)
data
# Out:
#                 created_at  retweet_count  is_allow              user_id  \
# 44367  2020-11-01 10:45:04             24      True             37034483
# 44424  2020-11-01 10:01:49             11      True             37034483
# 44355  2020-11-01 10:49:41             15      True             37034483
# 44436  2020-11-01 09:57:24             14      True             37034483
# 23641  2020-10-30 08:58:00              2      True             37034483
# ...                    ...            ...       ...                  ...
# 14011  2020-10-26 17:37:27              0      True  1307231165506416640
# 9520   2020-10-28 14:00:49            175      True  1306828323058671616
# 30211  2020-10-28 14:00:49            175      True  1306828323058671616
# 23409  2020-10-30 09:59:50              0      True  1296322416218578944
# 20778  2020-10-31 13:37:47            201      True  1312963204448948229
#
#                                         user_description  user_follower_count  \
# ...

# %%
#Question13
data.drop('tweet',axis=1,inplace=True)
data
# Out:
#                 created_at  retweet_count  is_allow              user_id  \
# 44367  2020-11-01 10:45:04             24      True             37034483
# 44424  2020-11-01 10:01:49             11      True             37034483
# 44355  2020-11-01 10:49:41             15      True             37034483
# 44436  2020-11-01 09:57:24             14      True             37034483
# 23641  2020-10-30 08:58:00              2      True             37034483
# ...                    ...            ...       ...                  ...
# 14011  2020-10-26 17:37:27              0      True  1307231165506416640
# 9520   2020-10-28 14:00:49            175      True  1306828323058671616
# 30211  2020-10-28 14:00:49            175      True  1306828323058671616
# 23409  2020-10-30 09:59:50              0      True  1296322416218578944
# 20778  2020-10-31 13:37:47            201      True  1312963204448948229
#
#                                         user_description  user_follower_count  \
# ...

# %%
#Question14
data.insert(1,'created_year',data['created_at'].str.split('-').str[0])
data.insert(2,'created_month',data['created_at'].str.split('-').str[1])
data
# Out:
#                 created_at created_year created_month  retweet_count  \
# 44367  2020-11-01 10:45:04         2020            11             24
# 44424  2020-11-01 10:01:49         2020            11             11
# 44355  2020-11-01 10:49:41         2020            11             15
# 44436  2020-11-01 09:57:24         2020            11             14
# 23641  2020-10-30 08:58:00         2020            10              2
# ...                    ...          ...           ...            ...
# 14011  2020-10-26 17:37:27         2020            10              0
# 9520   2020-10-28 14:00:49         2020            10            175
# 30211  2020-10-28 14:00:49         2020            10            175
# 23409  2020-10-30 09:59:50         2020            10              0
# 20778  2020-10-31 13:37:47         2020            10            201
#
#        is_allow              user_id  \
# 44367      True             37034483
# 44424      True             37034483
# ...
